# %% [markdown]
# # Check Ultralytics / YOLO11 Library

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\LIK\Documents\GitHub\segmentation-robot-navigation\python-code

# %%
# !nvidia-smi
# Out:
# Mon Nov 18 09:43:56 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.14                 Driver Version: 566.14         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070      WDDM  |   00000000:07:00.0  On |                  N/A |
# |  0%   39C    P8             18W /  270W |     629MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1968    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A      6508    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A      7124    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A      8140    C+G   ...n\NVIDIA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A      8380    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A      8472    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A      9636    C+G   ...n\NVIDIA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A     12680    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13648    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     15652    C+G   ...Desktop\app-3.4.9\GitHubDesktop.exe      N/A      |
# |    0   N/A  N/A     15968    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     16460    C+G   ...__8wekyb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A     16740    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Sep_12_02:55:00_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.77
# Build cuda_12.6.r12.6/compiler.34841621_0

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.32  Python-3.12.5 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# Setup complete  (16 CPUs, 31.9 GB RAM, 196.7/237.6 GB disk)

# %%
# !yolo task=segment mode=predict model=yolo11l-seg.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# Ultralytics 8.3.32 ðŸš€ Python-3.12.5 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# YOLO11l-seg summary (fused): 491 layers, 27,646,272 parameters, 0 gradients, 142.2 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 C:\Users\LIK\Documents\GitHub\segmentation-robot-navigation\python-code\dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 80.4ms
# Speed: 0.0ms preprocess, 80.4ms inference, 80.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs\segment\predict
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
import os
from IPython.display import Image as IPyImage

HOME = os.getcwd()
file_path = os.path.join(HOME, 'runs', 'segment', 'predict', 'dog.jpg')
IPyImage(filename=file_path, width=600)

# %%
from ultralytics import YOLO
from PIL import Image
import requests

model = YOLO('yolo11l-seg.pt')
image = Image.open(requests.get('https://media.roboflow.com/notebooks/examples/dog.jpeg', stream=True).raw)
result = model.predict(image, conf=0.25)[0]
# Out:
# 0: 640x384 1 person, 1 car, 1 dog, 1 backpack, 74.3ms
# Speed: 1.2ms preprocess, 74.3ms inference, 78.1ms postprocess per image at shape (1, 3, 640, 384)

# %%
import supervision as sv

detections = sv.Detections.from_ultralytics(result)

# %%
mask_annotator = sv.MaskAnnotator()
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK, text_position=sv.Position.CENTER)

annotated_image = image.copy()
annotated_image = mask_annotator.annotate(annotated_image, detections=detections)
annotated_image = label_annotator.annotate(annotated_image, detections=detections)

sv.plot_image(annotated_image, size=(10, 10))

# %% [markdown]
# # Training Custom Dataset YOLO11 Instance Segmentation

# %%
jupyter nbextension enable --py widgetsnbextension
# Out:
#   Cell In[1], line 1
#     jupyter nbextension enable --py widgetsnbextension
#             ^
# SyntaxError: invalid syntax

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
HOME = os.getcwd()
HOME
# Out:
# 'C:\\Users\\LIK\\Documents\\GitHub\\segmentation-robot-navigation\\python-code'

# %%
import os
os.makedirs("datasets")

# %%
file_path = os.path.join(HOME, 'datasets')
print(file_path)
# Out:
# C:\Users\LIK\Documents\GitHub\segmentation-robot-navigation\python-code\datasets

# %%
# !cd {HOME}/datasets
# !cd
# Out:
# C:\Users\LIK\Documents\GitHub\segmentation-robot-navigation\python-code

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="uZ6Fr7pg6ezFrqbUPjJB")
project = rf.workspace("rameshprabha").project("drivable_area1")
version = project.version(8)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in drivable_area1-8 to yolov11:: 100%|███████| 145159/145159 [00:18<00:00, 8046.46it/s]
# Extracting Dataset Version Zip to drivable_area1-8 in yolov11:: 100%|████████████| 3855/3855 [00:01<00:00, 2527.07it/s]

# %%
# !cd {HOME}
# !cd
# Out:
# C:\Users\LIK\Documents\GitHub\segmentation-robot-navigation\python-code

# %%
# !yolo task=detect mode=train model=yolo11s-seg.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 plots=True

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/segment/train/confusion_matrix.png', width=600)
